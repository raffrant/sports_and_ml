# %%
competition='E'

# %%
from euroleague_api.boxscore_data import BoxScoreData

# %%
boxscoredata=BoxScoreData(competition=competition)

# %%
boxscore_q_df=boxscoredata.get_game_boxscore_quarter_data(season=2025,gamecode=300)

# %%
boxscore_q_df
# Out:
#    Season  Gamecode                        Team  Quarter1  Quarter2  Quarter3  \
# 0    2025       300          OLYMPIACOS PIRAEUS        20        20        18
# 1    2025       300  PANATHINAIKOS AKTOR ATHENS        13        16        27
#
#    Quarter4
# 0        28
# 1        24

# %%
boxscore_stats_df=boxscoredata.get_player_boxscore_stats_data(season=2025,gamecode=300)

# %%
boxscore_stats_df
# Out:
#     Season  Gamecode  Home   Player_ID  IsStarter  IsPlaying Team Dorsal  \
# 0     2025       300     1  P006591           1.0        1.0  OLY      1
# 1     2025       300     1  P012610           0.0        1.0  OLY      3
# 2     2025       300     1  P010392           0.0        0.0  OLY      5
# 3     2025       300     1  P001255           1.0        0.0  OLY     16
# 4     2025       300     1  P009849           1.0        0.0  OLY     22
# 5     2025       300     1  P008829           1.0        0.0  OLY     25
# 6     2025       300     1  P003941           1.0        1.0  OLY     33
# 7     2025       300     1  P014316           0.0        1.0  OLY     34
# 8     2025       300     1  P011196           0.0        0.0  OLY     45
# 9     2025       300     1  P007853           0.0        0.0  OLY     77
# 10    2025       300     1  P011981           0.0        0.0  OLY     88
# 11    2025       300     1  P013380           0.0        1.0  OLY     94
# 12    2025       300     1        Team        0.0        0.0  OLY
# 13    2025       300     1       Total        NaN        NaN  OLY    NaN
# 14    2025       300     0  P012608           0.0        0.0  PAN      0
# 15    2025       300     0  P004088           1.0        1.0  PAN      6
# 16    2025       300     0  P014011           1.0        0.0  PAN      8
# 17    2025       300     0  P001926           0.0        0.0  PAN     10
# 18    2025       300     0  P008962           0.0        1.0  PAN     11
# 19    2025       300     0  P011085           0.0        0.0  PAN     17
# 20    2025       300     0  P011204           1.0        1.0  PAN     22
# 21    2025       300     0  P012774           1.0        1.0  PAN     25
# 22    2025       300     0  P004292           0.0        0.0  PAN     27
# 23    2025       300     0  P011284           0.0        0.0  PAN     35
# 24    2025       300     0  P012712           1.0        1.0  PAN     41
# 25    2025       300     0  P007866           0.0        0.0  PAN     44
# 26    2025       300     0        Team        0.0        0.0  PAN
# 27    2025       300     0       Total        NaN        NaN  PAN    NaN
#
#                      Player Minutes  ...  TotalRebounds  Assistances  Steals  \
# 0          NTILIKINA, FRANK   21:51  ...              1            0       2
# 1               WARD, TYSON   21:36  ...              3            3       1
# 2   LARENTZAKIS, GIANNOULIS     DNP  ...              0            0       0
# 3      PAPANIKOLAOU, KOSTAS   16:09  ...              2            1       0
# 4             DORSEY, TYLER   20:12  ...              4            4       1
# 5              PETERS, ALEC   18:24  ...              3            1       0
# 6         MILUTINOV, NIKOLA   22:59  ...              4            1       0
# 7              JOSEPH, CORY   18:20  ...              4            2       1
# 8               HALL, DONTA     DNP  ...              0            0       0
# 9      MCKISSIC, SHAQUIELLE   18:56  ...              2            4       2
# 10           JONES, TYRIQUE   17:01  ...              6            3       1
# 11           FOURNIER, EVAN   24:32  ...              2            3       2
# 12                     Team    None  ...              2            0       0
# 13                    Total  200:00  ...             33           22      10
# 14               SHORTS, TJ   03:51  ...              1            0       0
# 15              OSMAN, CEDI   32:38  ...              3            2       1
# 16          HOLMES, RICHAUN   16:34  ...              3            1       0
# 17          SLOUKAS, KOSTAS   15:20  ...              0            3       0
# 18       HAYES-DAVIS, NIGEL   22:42  ...              3            0       3
# 19  ROGKAVOPOULOS, NIKOLAOS   05:11  ...              3            0       0
# 20            GRANT, JERIAN   28:18  ...              1            4       1
# 21           NUNN, KENDRICK   32:53  ...              0            6       0
# 22    TOLIOPOULOS, VASSILIS     DNP  ...              0            0       0
# 23          FARIED, KENNETH   03:22  ...              0            0       0
# 24     HERNANGOMEZ, JUANCHO   23:10  ...              7            0       1
# 25   MITOGLOU, KONSTANTINOS   16:01  ...              2            1       1
# 26                     Team    None  ...              6            0       0
# 27                    Total  200:00  ...             29           17       7
#
#     Turnovers  BlocksFavour  BlocksAgainst  FoulsCommited  FoulsReceived  \
# 0           1             1              0              1              2
# 1           3             0              0              4              0
# 2           0             0              0              0              0
# 3           0             0              0              3              1
# 4           1             1              1              5              2
# 5           1             0              0              1              3
# 6           2             1              0              0              3
# 7           2             0              0              0              5
# 8           0             0              0              0              0
# 9           0             0              0              3              4
# 10          2             0              0              2              1
# 11          0             0              0              2              1
# 12          2             0              0              0              0
# 13         14             3              1             21             22
# 14          1             0              1              1              0
# 15          1             0              0              3              4
# 16          1             0              1              4              1
# 17          2             0              0              1              1
# 18          3             0              0              4              3
# 19          0             0              0              1              0
# 20          0             0              1              3              5
# 21          6             0              0              2              4
# 22          0             0              0              0              0
# 23          1             0              0              0              0
# 24          2             1              0              4              2
# 25          0             0              0              1              0
# 26          0             0              0              0              0
# 27         17             1              3             24             20
#
#     Valuation  Plusminus
# 0          11        5.0
# 1           9        8.0
# 2           0        0.0
# 3           5       -3.0
# 4          14        0.0
# 5           7       -2.0
# 6          18       -3.0
# 7          14        2.0
# 8           0        0.0
# 9          14       11.0
# 10          6        9.0
# 11          4        3.0
# 12          0        NaN
# 13        102        NaN
# 14         -4       -3.0
# 15         15        2.0
# 16          1        4.0
# 17         -1       -7.0
# 18         11       -9.0
# 19          3       -8.0
# 20         12        0.0
# 21         17       -2.0
# 22          0        0.0
# 23         -1       -1.0
# 24         17        5.0
# 25          3      -11.0
# 26          6        NaN
# 27         79        NaN
#
# [28 rows x 29 columns]

# %%
boxscore_stats_df.columns
# Out:
# Index(['Season', 'Gamecode', 'Home', 'Player_ID', 'IsStarter', 'IsPlaying',
#        'Team', 'Dorsal', 'Player', 'Minutes', 'Points', 'FieldGoalsMade2',
#        'FieldGoalsAttempted2', 'FieldGoalsMade3', 'FieldGoalsAttempted3',
#        'FreeThrowsMade', 'FreeThrowsAttempted', 'OffensiveRebounds',
#        'DefensiveRebounds', 'TotalRebounds', 'Assistances', 'Steals',
#        'Turnovers', 'BlocksFavour', 'BlocksAgainst', 'FoulsCommited',
#        'FoulsReceived', 'Valuation', 'Plusminus'],
#       dtype='object')

# %%
boxscore_stats_panatha=boxscore_stats_df[boxscore_stats_df["Team"]=="PAN"]
boxscore_stats_oly=boxscore_stats_df[boxscore_stats_df["Team"]=="OLY"]

# %%
boxscore_stats_panatha
# Out:
#     Season  Gamecode  Home   Player_ID  IsStarter  IsPlaying Team Dorsal  \
# 14    2025       300     0  P012608           0.0        0.0  PAN      0
# 15    2025       300     0  P004088           1.0        1.0  PAN      6
# 16    2025       300     0  P014011           1.0        0.0  PAN      8
# 17    2025       300     0  P001926           0.0        0.0  PAN     10
# 18    2025       300     0  P008962           0.0        1.0  PAN     11
# 19    2025       300     0  P011085           0.0        0.0  PAN     17
# 20    2025       300     0  P011204           1.0        1.0  PAN     22
# 21    2025       300     0  P012774           1.0        1.0  PAN     25
# 22    2025       300     0  P004292           0.0        0.0  PAN     27
# 23    2025       300     0  P011284           0.0        0.0  PAN     35
# 24    2025       300     0  P012712           1.0        1.0  PAN     41
# 25    2025       300     0  P007866           0.0        0.0  PAN     44
# 26    2025       300     0        Team        0.0        0.0  PAN
# 27    2025       300     0       Total        NaN        NaN  PAN    NaN
#
#                      Player Minutes  ...  TotalRebounds  Assistances  Steals  \
# 14               SHORTS, TJ   03:51  ...              1            0       0
# 15              OSMAN, CEDI   32:38  ...              3            2       1
# 16          HOLMES, RICHAUN   16:34  ...              3            1       0
# 17          SLOUKAS, KOSTAS   15:20  ...              0            3       0
# 18       HAYES-DAVIS, NIGEL   22:42  ...              3            0       3
# 19  ROGKAVOPOULOS, NIKOLAOS   05:11  ...              3            0       0
# 20            GRANT, JERIAN   28:18  ...              1            4       1
# 21           NUNN, KENDRICK   32:53  ...              0            6       0
# 22    TOLIOPOULOS, VASSILIS     DNP  ...              0            0       0
# 23          FARIED, KENNETH   03:22  ...              0            0       0
# 24     HERNANGOMEZ, JUANCHO   23:10  ...              7            0       1
# 25   MITOGLOU, KONSTANTINOS   16:01  ...              2            1       1
# 26                     Team    None  ...              6            0       0
# 27                    Total  200:00  ...             29           17       7
#
#     Turnovers  BlocksFavour  BlocksAgainst  FoulsCommited  FoulsReceived  \
# 14          1             0              1              1              0
# 15          1             0              0              3              4
# 16          1             0              1              4              1
# 17          2             0              0              1              1
# 18          3             0              0              4              3
# 19          0             0              0              1              0
# 20          0             0              1              3              5
# 21          6             0              0              2              4
# 22          0             0              0              0              0
# 23          1             0              0              0              0
# 24          2             1              0              4              2
# 25          0             0              0              1              0
# 26          0             0              0              0              0
# 27         17             1              3             24             20
#
#     Valuation  Plusminus
# 14         -4       -3.0
# 15         15        2.0
# 16          1        4.0
# 17         -1       -7.0
# 18         11       -9.0
# 19          3       -8.0
# 20         12        0.0
# 21         17       -2.0
# 22          0        0.0
# 23         -1       -1.0
# 24         17        5.0
# 25          3      -11.0
# 26          6        NaN
# 27         79        NaN
#
# [14 rows x 29 columns]

# %%
boxstore_single_df_2025=boxscoredata.get_player_boxscore_stats_single_season(season=2025)
# Out:
# Season 2025:   0%|          | 0/399 [00:00<?, ?it/s]

# %%
from euroleague_api.play_by_play_data import PlayByPlay

# %%
pbp_data=PlayByPlay(competition=competition)

# %%
pbp_data_df=pbp_data.get_game_play_by_play_data(season=2025,gamecode=300)

# %%
pbp_data_df.head()
# Out:
#    Season  Gamecode  TYPE  NUMBEROFPLAY CODETEAM PLAYER_ID PLAYTYPE  \
# 0    2025       300     0            15                          BP
# 1    2025       300     0            16      PAN                 JB
# 2    2025       300     0            17      PAN   P004088     3FGA
# 3    2025       300     0            18      PAN   P012712        O
# 4    2025       300     0            19      PAN   P012712     2FGM
#
#                  PLAYER                        TEAM DORSAL  MINUTE MARKERTIME  \
# 0                  None                        None   None       1
# 1                  None  Panathinaikos AKTOR Athens              1      09:59
# 2           OSMAN, CEDI  Panathinaikos AKTOR Athens      6       1      09:35
# 3  HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41       1      09:33
# 4  HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41       1      09:31
#
#    POINTS_A  POINTS_B COMMENT                            PLAYINFO  PERIOD  \
# 0       NaN       NaN                                Begin Period       1
# 1       NaN       NaN                                                   1
# 2       NaN       NaN          Missed Three Pointer (0/1 -  0 pt)       1
# 3       NaN       NaN                             Off Rebound (1)       1
# 4       NaN       2.0                   Two Pointer (1/1 -  2 pt)       1
#
#    TRUE_NUMBEROFPLAY
# 0                  0
# 1                  1
# 2                  2
# 3                  3
# 4                  4

# %%
pbp_data_df["PLAYTYPE"].unique()
# Out:
# array(['BP', 'JB', '3FGA', 'O', '2FGM', '3FGM', 'D', 'RV', 'CM', 'AS',
#        '2FGA', 'AG', 'FV', 'OUT', 'IN', 'FTM', 'TO', 'TOUT_TV', 'FTA',
#        'OF', 'ST', 'EP', 'TOUT', 'CMT', 'CMU', 'CCH', 'EG'], dtype=object)

# %%
pbp_data_df
# Out:
#      Season  Gamecode  TYPE  NUMBEROFPLAY CODETEAM PLAYER_ID PLAYTYPE  \
# 0      2025       300     0            15                          BP
# 1      2025       300     0            16      PAN                 JB
# 2      2025       300     0            17      PAN   P004088     3FGA
# 3      2025       300     0            18      PAN   P012712        O
# 4      2025       300     0            19      PAN   P012712     2FGM
# ..      ...       ...   ...           ...      ...       ...      ...
# 509    2025       300     0           574      OLY   P012610       IN
# 510    2025       300     0           575      OLY   P008829      OUT
# 511    2025       300     0           576      PAN   P004088     3FGA
# 512    2025       300     0           577      OLY   P003941        D
# 513    2025       300     0           580                          EG
#
#                    PLAYER                        TEAM DORSAL  MINUTE  \
# 0                    None                        None   None       1
# 1                    None  Panathinaikos AKTOR Athens              1
# 2             OSMAN, CEDI  Panathinaikos AKTOR Athens      6       1
# 3    HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41       1
# 4    HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41       1
# ..                    ...                         ...    ...     ...
# 509           WARD, TYSON          Olympiacos Piraeus      3      40
# 510          PETERS, ALEC          Olympiacos Piraeus     25      40
# 511           OSMAN, CEDI  Panathinaikos AKTOR Athens      6      40
# 512     MILUTINOV, NIKOLA          Olympiacos Piraeus     33      40
# 513                  None                        None   None      41
#
#     MARKERTIME  POINTS_A  POINTS_B COMMENT  \
# 0                    NaN       NaN
# 1        09:59       NaN       NaN
# 2        09:35       NaN       NaN
# 3        09:33       NaN       NaN
# 4        09:31       NaN       2.0
# ..         ...       ...       ...     ...
# 509      00:09       NaN       NaN
# 510      00:09       NaN       NaN
# 511      00:01       NaN       NaN
# 512      00:00       NaN       NaN
# 513                  NaN       NaN
#
#                                 PLAYINFO  PERIOD  TRUE_NUMBEROFPLAY
# 0                           Begin Period       1                  0
# 1                                              1                  1
# 2     Missed Three Pointer (0/1 -  0 pt)       1                  2
# 3                        Off Rebound (1)       1                  3
# 4              Two Pointer (1/1 -  2 pt)       1                  4
# ..                                   ...     ...                ...
# 509                                   In       4                509
# 510                                  Out       4                510
# 511  Missed Three Pointer (2/6 -  14 pt)       4                511
# 512                      Def Rebound (3)       4                512
# 513                             End Game       4                513
#
# [514 rows x 18 columns]

# %%
pbp_lineups_df=pbp_data.get_pbp_data_with_lineups(season=2025,gamecode=300)

# %%
pbp_lineups_df.head()
# Out:
#    Season  Gamecode  TYPE  NUMBEROFPLAY CODETEAM PLAYER_ID PLAYTYPE  \
# 0    2025       300     0            15                          BP
# 1    2025       300     0            16      PAN                 JB
# 2    2025       300     0            17      PAN   P004088     3FGA
# 3    2025       300     0            18      PAN   P012712        O
# 4    2025       300     0            19      PAN   P012712     2FGM
#
#                  PLAYER                        TEAM DORSAL  ...  POINTS_A  \
# 0                  None                        None   None  ...       NaN
# 1                  None  Panathinaikos AKTOR Athens         ...       NaN
# 2           OSMAN, CEDI  Panathinaikos AKTOR Athens      6  ...       NaN
# 3  HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41  ...       NaN
# 4  HERNANGOMEZ, JUANCHO  Panathinaikos AKTOR Athens     41  ...       NaN
#
#   POINTS_B  COMMENT                            PLAYINFO PERIOD IsHomeTeam  \
# 0      NaN                                 Begin Period      1       None
# 1      NaN                                                   1       None
# 2      NaN           Missed Three Pointer (0/1 -  0 pt)      1       None
# 3      NaN                              Off Rebound (1)      1       None
# 4      2.0                    Two Pointer (1/1 -  2 pt)      1       None
#
#    TRUE_NUMBEROFPLAY                                           Lineup_A  \
# 0                  0  [NTILIKINA, FRANK, PAPANIKOLAOU, KOSTAS, DORSE...
# 1                  1  [NTILIKINA, FRANK, PAPANIKOLAOU, KOSTAS, DORSE...
# 2                  2  [NTILIKINA, FRANK, PAPANIKOLAOU, KOSTAS, DORSE...
# 3                  3  [NTILIKINA, FRANK, PAPANIKOLAOU, KOSTAS, DORSE...
# 4                  4  [NTILIKINA, FRANK, PAPANIKOLAOU, KOSTAS, DORSE...
#
#                                             Lineup_B validate_on_court_player
# 0  [OSMAN, CEDI, HOLMES, RICHAUN, GRANT, JERIAN, ...                     True
# 1  [OSMAN, CEDI, HOLMES, RICHAUN, GRANT, JERIAN, ...                     True
# 2  [OSMAN, CEDI, HOLMES, RICHAUN, GRANT, JERIAN, ...                     True
# 3  [OSMAN, CEDI, HOLMES, RICHAUN, GRANT, JERIAN, ...                     True
# 4  [OSMAN, CEDI, HOLMES, RICHAUN, GRANT, JERIAN, ...                     True
#
# [5 rows x 22 columns]

# %%
pbp_data_df_2024=pbp_data.get_game_play_by_play_data_single_season(season=2024)
# Out:
# Season 2024:   0%|          | 0/330 [00:00<?, ?it/s]

# %%
pbp_data_df_2024.head()
# Out:
#    Season Phase  Round  Gamecode  TYPE  NUMBEROFPLAY CODETEAM PLAYER_ID  \
# 0    2024    RS      1         1     0            49
# 1    2024    RS      1         1     0            50      PAN
# 2    2024    RS      1         1     0            51      PAN   P002328
# 3    2024    RS      1         1     0            52      BER   P006919
# 4    2024    RS      1         1     0            53      BER   P010791
#
#   PLAYTYPE             PLAYER                        TEAM DORSAL  MINUTE  \
# 0       BP               None                        None   None       1
# 1       JB               None  Panathinaikos AKTOR Athens              1
# 2     2FGA   GRIGONIS, MARIUS  Panathinaikos AKTOR Athens     40       1
# 3        D      OLINDE, LOUIS                 ALBA Berlin     19       1
# 4     2FGA  KOUMADJE, KHALIFA                 ALBA Berlin     21       1
#
#   MARKERTIME  POINTS_A  POINTS_B COMMENT                          PLAYINFO  \
# 0                  NaN       NaN                              Begin Period
# 1      09:59       NaN       NaN
# 2      09:49       NaN       NaN          Missed Two Pointer (0/1 -  0 pt)
# 3      09:46       NaN       NaN                           Def Rebound (1)
# 4      09:30       NaN       NaN          Missed Two Pointer (0/1 -  0 pt)
#
#    PERIOD  TRUE_NUMBEROFPLAY
# 0       1                  0
# 1       1                  1
# 2       1                  2
# 3       1                  3
# 4       1                  4

# %%
from euroleague_api.shot_data import ShotData

# %%
shotdata=ShotData(competition='E')

# %%
shotdata_df=shotdata.get_game_shot_data(season=2025,gamecode=300)

# %%
shotdata_df.head()
# Out:
#    Season  Gamecode  NUM_ANOT TEAM ID_PLAYER                PLAYER ID_ACTION  \
# 0    2025       300        17  PAN   P004088           OSMAN, CEDI      3FGA
# 1    2025       300        19  PAN   P012712  HERNANGOMEZ, JUANCHO      2FGM
# 2    2025       300        20  OLY   P009849         DORSEY, TYLER      3FGM
# 3    2025       300        22  PAN   P012712  HERNANGOMEZ, JUANCHO      3FGA
# 4    2025       300        26  OLY   P001255  PAPANIKOLAOU, KOSTAS      3FGM
#
#                  ACTION  POINTS  COORD_X  COORD_Y ZONE FASTBREAK  \
# 0  Missed Three Pointer       0      -37      721    H         0
# 1           Two Pointer       2      -87       81    B         0
# 2         Three Pointer       3     -401      602    H         0
# 3  Missed Three Pointer       0     -457      514    H         0
# 4         Three Pointer       3      483      552    I         0
#
#   SECOND_CHANCE POINTS_OFF_TURNOVER  MINUTE CONSOLE  POINTS_A  POINTS_B  \
# 0             0                   0       1   09:35         0         0
# 1             1                   0       1   09:31         0         2
# 2             0                   0       1   09:16         3         2
# 3             0                   0       2   08:51         3         2
# 4             0                   0       2   08:36         6         2
#
#               UTC
# 0  20260306191619
# 1  20260306191623
# 2  20260306191638
# 3  20260306191703
# 4  20260306191738

# %% [markdown]
# Shot data of single seasons.

# %%
shotdata_s2024_df=shotdata.get_game_shot_data_single_season(season=2025)
# Out:
# Season 2025:   0%|          | 0/399 [00:00<?, ?it/s]

# %%
shotdata_s2024_df["ID_ACTION"]
# Out:
# 0        2FGM
# 1        3FGA
# 2        2FGM
# 3        2FGM
# 4         FTM
#          ...
# 63655     FTM
# 63656     FTM
# 63657    2FGA
# 63658     FTM
# 63659     FTM
# Name: ID_ACTION, Length: 63660, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle,Arc
def draw_court(ax=None, color='black', lw=1, outer_lines=True):
    """
    FIBA basketball court dimensions:
    https://www.msfsports.com.au/basketball-court-dimensions/
    It seems like the Euroleauge API returns the shooting positions
    in resolution of 1cm x 1cm.
    """
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 45.72cm so it has a radius 45.72/2 cms
    hoop = Circle((0, 0), radius=45.72 / 2, linewidth=lw, color=color,
                  fill=False)

    # Create backboard
    backboard = Rectangle((-90, -157.5 + 120), 180, -1, linewidth=lw,
                          color=color)

    # The paint
    # Create the outer box of the paint
    outer_box = Rectangle((-490 / 2, -157.5), 490, 580, linewidth=lw,
                          color=color, fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-360 / 2, -157.5), 360, 580, linewidth=lw,
                          color=color, fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 580 - 157.5), 360, 360, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 580 - 157.5), 360, 360, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 2 * 125, 2 * 125, theta1=0, theta2=180,
                     linewidth=lw, color=color)

    # Three point line
    # Create the side 3pt lines
    corner_three_a = Rectangle((-750 + 90, -157.5), 0, 305, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((750 - 90, -157.5), 0, 305, linewidth=lw,
                               color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the
    # threes
    three_arc = Arc((0, 0), 2 * 675, 2 * 675, theta1=12, theta2=167.5,
                    linewidth=lw, color=color)

    # Center Court
    center_outer_arc = Arc((0, 1400-157.5), 2 * 180, 2 * 180, theta1=180,
                           theta2=0, linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box,
                      restricted, top_free_throw, bottom_free_throw,
                      corner_three_a, corner_three_b, three_arc,
                      center_outer_arc]
    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-750, -157.5), 1500, 1400, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
def plot_scatter(made, miss, title=None):
    """
    Scatter plot of made and missed shots
    """
    plt.figure()
    draw_court()
    plt.plot(made['COORD_X'], made['COORD_Y'], 'o', label='Made')
    plt.plot(miss['COORD_X'], miss['COORD_Y'], 'x', markerfacecolor='none',
             label='Missed')
    plt.legend()
    plt.xlim([-800, 800])
    plt.ylim([-200, 1300])
    plt.title(title)
    plt.show()
    return

# %%
import pandas as pd
team="MAD"
team_shot_df=shotdata_s2024_df[shotdata_s2024_df["TEAM"]==team]
team_made=team_shot_df[team_shot_df["ID_ACTION"].str.contains("FGM")]
team_missed=team_shot_df[team_shot_df["ID_ACTION"].str.contains("FGA")]



#pd.concat([team_shot_df[team_shot_df["ID_ACTION"]=="2FGM"], team_shot_df[team_shot_df["ID_ACTION"]=="3FGM"]])
#team_missed=pd.concat([team_shot_df[team_shot_df["ID_ACTION"]=="2FGA"], team_shot_df[team_shot_df["ID_ACTION"]=="3FGA"]])
#teams_shot_miss_df=team_shot_df["ID_ACTION"]
#teams_shot_miss_df.head()
#teams_shot_made_df=team_shot_df[team_shot_df["ID_ACTION"]=="FGM"]

# %%
plot_scatter(team_made,team_missed,title="PAN")

# %%
shotdata_s2024_df["PLAYER"].unique()
# Out:
# array(['JONES, KAI', 'LARKIN, SHANE', 'OSMANI, ERCAN', 'SORKIN, ROMAN',
#        'WEILER-BABB, NICK', "BRISSETT, O'SHAE J", 'CORDINIER, ISAIA',
#        'CLARK III, JIMMY', 'HOARD, JAYLEN', 'BLATT, TAMIR',
#        'PAPAGIANNIS, GEORGIOS', 'WALKER IV, LONNIE', 'SANTOS, MARCIO',
#        'DOWTIN JR, JEFFREY', 'LEAF, TJ', 'DIBARTOLOMEO, JOHN',
#        'HAZER, SEHMUS', 'LOYD, JORDAN', 'SMITS, ROLANDS',
#        'TRIFUNOVIC, UROS', 'RAYMAN, WILLIAM', 'HOWARD, MARKUS',
#        'VEZENKOV, SASHA', 'DIALLO, HAMIDOU', 'DORSEY, TYLER',
#        'FORREST, TRENT', 'MILUTINOV, NIKOLA', 'WALKUP, THOMAS',
#        'FOURNIER, EVAN', 'SAMANIC, LUKA', 'LUWAWU-CABARROT, TIMOTHE',
#        'NOWELL, MARKQUIS', 'FRISCH, CLEMENT', 'PETERS, ALEC',
#        'SEDEKERSKIS, TADAS', 'HALL, DONTA', 'LEE, SABEN', 'WARD, TYSON',
#        'SPAGNOLO, MATTEO', 'DIOP, KHALIFA', 'BOLMARO, LEANDRO',
#        'NWORA, JORDAN', 'SHIELDS, SHAVON', 'RIVERO, JASIEL',
#        'LEDAY, ZACH', 'MILLER-MCINTYRE, CODI', 'MONEKE, CHIMA',
#        'NEBO, JOSH', 'ELLIS, QUINN', 'EBUKA, IZUNDU', 'CARTER, TYSON',
#        'BOOKER, DEVIN', 'GUDURIC, MARKO', 'MILJENOVIC, STEFAN',
#        'OJELEYE, SEMI', 'CANCAR, VLATKO', 'DAVIDOVAC, DEJAN',
#        'KALINIC, NIKOLA', 'BROOKS, ARMONI', 'MANNION, NICCOLO',
#        'RICCI, GIAMPAOLO', 'BERTANS, DAVIS', 'PARKER, JABARI',
#        'MUSA, DZANAN', 'OSETKOWSKI, DYLAN', 'KABENGELE, MFIONDU',
#        'WASHINGTON, DUANE', 'LAKIC, ARIJAN', 'PETRUSEV, FILIP',
#        'WRIGHT IV, MCKINLEY', 'BACON, DWAYNE', 'BROWN, STERLING',
#        'ABASS, AWUDU', 'JONES, CARLIK', 'JONES, TYRIQUE', 'MILTON, SHAKE',
#        'MARINKOVIC, VANJA', 'BONGA, ISAAC', 'PREPELIC, KLEMEN',
#        'ANDERSON, JUSTIN', 'POKUSEVSKI, ALEKSEJ', 'SATORANSKY, TOMAS',
#        'MICIC, VASILIJE', 'PUNTER, KEVIN', 'CLYBURN, WILL',
#        'WAINRIGHT, ISH', 'MALCOLM, COLLIN', 'BRYANT, ELIJAH',
#        'OTURU, DAN', 'SHENGELIA, TORNIKE', 'JONES, CHRIS',
#        'MOTLEY, JOHNATHAN', 'LAPROVITTOLA, NICOLAS', 'BLAKENEY, ANTONIO',
#        'BRIZUELA, DARIO', 'GINAT, TOMER', 'PARRA, JOEL', 'VESELY, JAN',
#        'HERNANGOMEZ, WILLY', 'FALL, YOUSSOUPHA', 'CALE, MYLES',
#        'SHORTS, TJ', 'RATHAN-MAYES, XAVIER', 'MIKE, ISIAHA',
#        'HOLMES, RICHAUN', 'HERNANGOMEZ, JUANCHO',
#        'ROGKAVOPOULOS, NIKOLAOS', 'GABRIEL, WENYEN', 'JOVIC, STEFAN',
#        'NUNN, KENDRICK', 'OBST, ANDREAS', 'GIFFEY, NIELS',
#        'JESSUP, JUSTINIAN', 'MITOGLOU, KONSTANTINOS', 'YURTSEVEN, OMER',
#        'SLOUKAS, KOSTAS', 'MCCORMACK, DAVID', 'GRIGONIS, MARIUS',
#        'GRANT, JERIAN', 'DA SILVA, OSCAR', 'BALDWIN, KAMAR',
#        'SAMODUROV, ALEXANDROS', 'LUCIC, VLADIMIR', 'OKEKE, CHUMA',
#        'EDWARDS, CARSEN', 'TAVARES, WALTER', 'SMAILAGIC, ALEN',
#        'HEZONJA, MARIO', 'PAJOLA, ALESSANDRO', 'JALLOW, KARIM',
#        'DECK, GABRIEL', 'VILDOZA, LUCA', 'FERNANDO, BRUNO',
#        'KRAEMER, DAVID', 'DIOUF, MOUHAMET', 'DIARRA, ALIOU',
#        'CAMPAZZO, FACUNDO', 'NIANG, SALIOU', 'LYLES, TREY',
#        'MORGAN, MATTHEW', 'LLULL, SERGIO', 'GARUBA, USMAN',
#        'FELIZ, ANDRES', 'TAYLOR, BRANDON', 'ABALDE, ALBERTO',
#        'ALSTON JR. , DERRICK', 'HACKETT, DANIEL', 'ROBINSON, JUSTIN',
#        'HALL, DEVON', 'HORTON TUCKER, TALEN', "M'BAYE, AMATH",
#        'COLSON, BONZIE', 'JANTUNEN, MIKAEL', 'BACOT JR., ARMANDO',
#        'HIFI, NADIR', 'HOMMES, DAULTON', 'WILLIS, DEREK', 'MELLI, NICOLO',
#        'MORGAN, JEREMY', 'BALDWIN IV, WADE', 'CAVALIERE, LEOPOLD',
#        'BIBEROVIC, TARIK', 'OUATTARA, YAKUBA', 'BOSTON JR., BRANDON',
#        'BIRSEN, METECAN', 'BITIM, ONURALP', 'BIRCH, KHEM',
#        'HERRERA, SEBASTIAN', 'DOKOSSI, ALLAN', 'FAYE, MOUHAMED',
#        'JAMES, MIKE', 'BIRUTIS, LAURYNAS', 'OKOBO, ELIE',
#        'WILLIAMS-GOSS, NIGEL', 'THEIS, DANIEL', 'DIALLO, ALPHA',
#        'SLEVA, DUSTIN', 'FRANCISCO, SYLVAIN', 'MIROTIC, NIKOLA',
#        'LO, MAODO', 'WRIGHT, MOSES', 'TUBELIS, AZUOLAS',
#        'BRAZDEIKIS, IGNAS', 'BLOSSOMGAME, JARON', 'STRAZEL, MATTHEW',
#        'NEDOVIC, NEMANJA', 'SIRVYDIS, DEIVIDAS', 'ULANOVAS, EDGARAS',
#        'HAYES, KEVARRIUS', 'BUTKEVICIUS, ARNAS', 'AJINCA, MELVIN',
#        'HARRISON, SHAQUILLE', 'TAYLOR, KAMERON', 'DE COLO, NANDO',
#        'VAUTIER, BASTIEN', 'REUVERS, NATHAN', 'SESTINA, NATHAN',
#        'MOORE, OMARI', 'DE LARREA, SERGIO', 'SAKO, NEAL',
#        'SELJAAS, ZACHARY', 'THOMPSON, DARIUS', 'PUERTO, JOSEP',
#        'WATSON, GLYNN', 'LIGHTY, DAVID', 'IROEGBU, IKE', 'JACKSON, EDWIN',
#        'TRAORE, ARMEL', 'COSTELLO, MATTHEW', 'PRADILLA, JAIME',
#        'MASSA, BODIAN', 'NDIAYE, MBAYE', 'IZUNDU, EBUKA', 'KRAMER, DAVID',
#        'PAPANIKOLAOU, KOSTAS', 'ANTETOKOUNMPO, KOSTAS', 'ENNIS, TYLER',
#        'ODIASE, TAI', 'AYAYI, JOEL', 'BAKO, ISMAEL', 'KAMENJAS, KENAN',
#        'KONDIC, KOSTA', 'TARPEY, TERRY', 'ATAMNA, ADAM',
#        'DIAKITE, MAMADI', 'OSMAN, CEDI', 'NORRIS, MILES',
#        'KALAITZAKIS, PANAGIOTIS', 'NOGUES, ISAAC', 'KURUCS, RODIONS',
#        'BROWN, LORENZO', 'NGOUAMA, MEHDY', 'ALMANSA, IZAN', 'DOZIER, PJ',
#        'SWIDER, COLE', 'NTILIKINA, FRANK', 'DANGUBIC, NEMANJA',
#        'ANDJUSIC, DANILO', 'NETZIPOGLOU, OMIROS',
#        'LARENTZAKIS, GIANNOULIS', 'MARCOS, JUANI', 'BADIO, BRANCOU',
#        'HOLLATZ, JUSTUS', 'KRATZER, LEON', 'RUBSTAVICIUS, MANTAS',
#        'MOTIEJUNAS, DONATAS', 'DOS SANTOS, YAGO', 'MAHMUTOGLU, MELIH',
#        'DUNSTON, BRYANT', 'WILBEKIN, SCOTTIE', 'ZAGARS, ARTURS',
#        'ARMSTRONG, TARAN', 'BEAUBOIS, RODRIGUE', 'KEITA, SAYON',
#        'GUR, LAVI', 'MALEDON, THEO', 'MUURINEN, MIIKKA',
#        'LOPEZ-AROSTEGUI, XABI', 'DIOP, OUSMANE', 'MONTERO, JEAN',
#        'SIMMONS, KOBI', 'JOKSIMOVIC, STEFAN', 'DOBRIC, OGNJEN',
#        'DESSERT, BRICE', 'YILMAZ, ERKAN', 'MCKISSIC, SHAQUIELLE',
#        'SHAHRVIN, ENZO', 'SANLI, SERTAC', 'VILLAR, RAFA', 'PLAVSIC, UROS',
#        'VOIGTMANN, JOHANNES', 'DINWIDDIE, SPENCER', 'BUTLER, JARED',
#        'PROCIDA, GABRIELE', 'ELLIS, BOOGIE', 'MIKALAUSKAS, KAJUS',
#        'CALATHES, NICK', 'TOLIOPOULOS, VASSILIS', 'LAVI, GUR',
#        'MAKOUNDOU, YOAN', 'KEY, BRAXTON', 'PALATIN, GUY', 'TIMOR, BAR',
#        'FARIED, KENNETH', 'SIMA, YANKUBA', 'LEN, ALEX',
#        'AVRAMOVIC, ALEKSA', 'TONUT, STEFANO', 'HEURTEL, THOMAS',
#        'BEGARIN, JUHANN', 'MUTAF, DAVID', 'TOTE, LEONARDO', 'SEGEV, ITAY',
#        'RYAN, MATT', 'RHODEN, JARED', 'OMORUYI, CLIFFORD',
#        'AKELE, NICOLA', 'STEVENS, LAMAR', 'MICHINEAU, DAVID',
#        'GRAHAM, DEVONTE', 'LUNDBERG, IFFE', 'FLACCADORI, DIEGO',
#        'RADZEVICIUS, GYTIS', 'POIRIER, VINCENT', 'MADAR, YAM',
#        'KUSTURICA, NIKOLA', 'OMORUYI, EUGENE', 'GIEDRAITIS, DOVYDAS',
#        'PAYNE, CAMERON', 'MORRIS, MONTE', 'SILVA, CHRIS', 'EBOUA, PAUL',
#        'DIMITRIJEVIC, NENO', 'JEKIRI, TONYE', 'ANGOLA, BRAIAN',
#        'JOSEPH, CORY', 'FERRARI, FRANCESCO', 'ACCORSI, MATTEO',
#        'BOLOMBOY, JOEL', 'CABOCLO, BRUNO', 'RADANOV, ALEKSA',
#        'MIJAILOVIC, UROS', 'HANKINS, ZACHARY', 'BOL, JUOM',
#        'HAYES-DAVIS, NIGEL', 'RANDOLPH, LEVI', 'EDWARDS, KESSLER',
#        'BAIOCCHI, MATTEO', 'LESSORT, MATHIAS', 'HRABAR, VIT',
#        'NUNEZ, JUAN', 'NAKIC, MARIO'], dtype=object)

# %%
player="NUNN, KENDRICK"

# %%
player_shot_df=shotdata_s2024_df[shotdata_s2024_df["PLAYER"]==player]
# CORRECTED - Filter properly
#    print(f"FGA: {fga}, FTA: {fta}, PTS: {total_pts}")
#else:
#    print("No shots attempted")

player_made=player_shot_df[player_shot_df["ID_ACTION"].str.contains("FGM")]
plaey_missed=player_shot_df[player_shot_df["ID_ACTION"].str.contains("FGA")]

# %%
plot_scatter(player_made,plaey_missed,title="NUNN, 50.3%")

# %%
len(player_made)/(len(plaey_missed)+len(player_made))
# Out:
# 0.5039370078740157

# %%
def get_team_possessions(df):
  """
  https://hackastat.eu/en/learn-a-stat-possessions-and-pace/
  Poss = FGA + 0.44 FTA - OR + TO
  """
  fga = df[["twoPointersAttempted", "threePointersAttempted"]].sum(axis=1)
  fta = df["freeThrowsAttempted"]
  ofr = df["offensiveRebounds"]
  to = df["turnovers"]
  poss = fga + 0.44 * fta - ofr + to
  return poss
     
pd.options.plotting.backend = "plotly"

# %%
from euroleague_api.team_stats import TeamStats
from euroleague_api.player_stats import PlayerStats

# %%
teamstats = TeamStats(competition)
playerstats = PlayerStats(competition)

# %%
team_stats_2024_df = teamstats.get_team_stats(
    endpoint="advanced",
    params={"SeasonMode": "Single", "SeasonCode": "E2025"},
    # statistic_mode="Accumulated" # PerGame
)

players_stats_2024_df = playerstats.get_player_stats(
    endpoint="advanced",
    params={"SeasonMode": "Single", "SeasonCode": "E2024"},
    # statistic_mode="Accumulated" # PerGame
)

# %%
team_stats_2024_df
team_stats_2024_df.to_csv('teams.csv', index=False)
# Out:
#     teamRanking  gamesPlayed effectiveFieldGoalPercentage  \
# 0             1         30.0                        50.1%
# 1             2         29.0                        52.8%
# 2             3         30.0                        54.4%
# 3             4         30.0                          54%
# 4             5         30.0                        55.7%
# 5             6         29.0                        54.6%
# 6             7         29.0                        53.3%
# 7             8         30.0                        54.6%
# 8             9         30.0                        55.8%
# 9            10         30.0                        54.2%
# 10           11         28.0                        57.6%
# 11           12         30.0                          57%
# 12           13         30.0                        55.1%
# 13           14         29.0                          54%
# 14           15         29.0                        54.3%
# 15           16         30.0                        57.1%
# 16           17         30.0                        56.3%
# 17           18         30.0                        56.7%
# 18           19         30.0                        54.4%
# 19           20         29.0                          56%
#
#    trueShootingPercentage offensiveReboundsPercentage  \
# 0                   54.2%                       32.5%
# 1                   56.6%                       28.4%
# 2                   58.2%                       28.3%
# 3                   57.5%                       29.7%
# 4                   59.1%                       31.2%
# 5                   59.1%                       32.9%
# 6                   57.3%                       35.5%
# 7                     59%                       30.9%
# 8                   59.5%                       33.5%
# 9                   58.5%                       31.2%
# 10                  61.3%                       28.5%
# 11                  61.1%                       30.2%
# 12                  58.7%                       37.9%
# 13                  59.6%                       30.8%
# 14                  58.6%                       33.1%
# 15                  60.6%                       32.8%
# 16                  59.4%                       35.4%
# 17                    61%                       35.5%
# 18                  59.3%                       31.1%
# 19                  60.6%                       37.4%
#
#    defensiveReboundsPercentage reboundsPercentage  assistsToTurnoversRatio  \
# 0                        67.5%              48.6%                      1.2
# 1                        69.1%              47.9%                      1.4
# 2                        67.6%              47.8%                      1.4
# 3                        67.4%              48.3%                      1.4
# 4                        65.3%              48.6%                      1.4
# 5                        68.8%              51.6%                      1.2
# 6                        64.4%              49.5%                      1.2
# 7                        66.6%              48.6%                      1.4
# 8                        67.1%              49.9%                      1.5
# 9                        66.7%              48.9%                      1.6
# 10                       67.8%              49.3%                      1.3
# 11                       68.4%              49.7%                      1.6
# 12                       69.3%              53.8%                      1.4
# 13                       67.2%              49.5%                      1.8
# 14                         64%              48.2%                      1.7
# 15                         69%              50.9%                      1.7
# 16                       69.4%                52%                      1.6
# 17                         72%              54.5%                      1.4
# 18                       66.2%              48.7%                      1.9
# 19                       68.3%              53.2%                      1.7
#
#    assistsRatio turnoversRatio twoPointRate threePointRate freeThrowsRate  \
# 0         16.2%            13%        57.2%          42.8%          29.5%
# 1         16.8%          12.3%        61.3%          38.7%          24.6%
# 2         17.6%            13%        57.5%          42.5%          28.7%
# 3         18.1%          13.2%          56%            44%          24.9%
# 4           19%          13.5%        56.9%          43.1%          27.5%
# 5         16.4%          13.4%        57.6%          42.4%            32%
# 6         15.5%          12.9%        52.4%          47.6%          30.4%
# 7         17.9%          12.5%        57.2%          42.8%          32.4%
# 8         17.9%            12%        59.8%          40.2%          27.6%
# 9         17.9%            11%        62.9%          37.1%          30.6%
# 10        16.7%          12.4%        60.3%          39.7%          28.1%
# 11        18.6%          11.8%        57.6%          42.4%          32.6%
# 12        18.4%            13%        60.4%          39.6%            33%
# 13        18.2%            10%        62.8%          37.2%          37.3%
# 14        18.4%            11%        57.4%          42.6%          31.6%
# 15        18.8%            11%        61.5%          38.5%          31.4%
# 16        18.7%          11.7%        53.1%          46.9%          28.9%
# 17          18%          12.7%        58.3%          41.7%          35.5%
# 18        19.2%            10%          62%            38%          34.3%
# 19        19.8%          11.6%        56.5%          43.5%          37.7%
#
#    pointsFromTwoPointersPercentage pointsFromThreePointersPercentage  \
# 0                            47.6%                             34.1%
# 1                            53.4%                             30.8%
# 2                              48%                             35.1%
# 3                            48.3%                             36.3%
# 4                            49.1%                               35%
# 5                            46.5%                             34.5%
# 6                            41.6%                             40.6%
# 7                              49%                               32%
# 8                            49.6%                             34.1%
# 9                            53.1%                             28.5%
# 10                           51.9%                             31.8%
# 11                           45.6%                             35.9%
# 12                           50.9%                             31.1%
# 13                           50.6%                             27.3%
# 14                           46.7%                             34.5%
# 15                           49.4%                             33.4%
# 16                             45%                             39.1%
# 17                           47.1%                             33.1%
# 18                           50.3%                             29.4%
# 19                           46.9%                             32.3%
#
#    pointsFromFreeThrowsPercentage team.code team.tvCodes  \
# 0                           18.3%       ASV          ASV
# 1                           15.8%       PAR          PAR
# 2                           16.9%       IST          EFS
# 3                           15.4%       MUN          BAY
# 4                             16%       VIR          VIR
# 5                             19%       ULK          FBB
# 6                           17.9%       PRS          PBB
# 7                             19%       BAS          KBA
# 8                           16.4%       BAR          BAR
# 9                           18.3%       PAN          PAO
# 10                          16.3%       HTA          HTA
# 11                          18.5%       MIL          EA7
# 12                            18%       RED          CZV
# 13                          22.1%       DUB          DUB
# 14                          18.7%       TEL          MTA
# 15                          17.2%       ZAL          ZAL
# 16                          15.9%       PAM          VBC
# 17                          19.7%       MAD          RMB
# 18                          20.3%       MCO          ASM
# 19                          20.8%       OLY          OLY
#
#                              team.name  \
# 0              LDLC ASVEL Villeurbanne
# 1        Partizan Mozzart Bet Belgrade
# 2                Anadolu Efes Istanbul
# 3                     FC Bayern Munich
# 4                       Virtus Bologna
# 5             Fenerbahce Beko Istanbul
# 6                     Paris Basketball
# 7             Baskonia Vitoria-Gasteiz
# 8                         FC Barcelona
# 9           Panathinaikos AKTOR Athens
# 10                     Hapoel Tel Aviv
# 11            EA7 Emporio Armani Milan
# 12  Crvena Zvezda Meridianbet Belgrade
# 13                    Dubai Basketball
# 14              Maccabi Rapyd Tel Aviv
# 15                     Zalgiris Kaunas
# 16                     Valencia Basket
# 17                         Real Madrid
# 18                           AS Monaco
# 19                  Olympiacos Piraeus
#
#                                         team.imageUrl
# 0   https://media-cdn.incrowdsports.com/e33c6d1a-9...
# 1   https://media-cdn.incrowdsports.com/2681304e-7...
# 2   https://media-cdn.cortextech.io/9a463aa2-ceb2-...
# 3   https://media-cdn.incrowdsports.com/817b0e58-d...
# 4   https://media-cdn.cortextech.io/1362801d-dd09-...
# 5   https://media-cdn.cortextech.io/3b7f020e-5b39-...
# 6   https://media-cdn.incrowdsports.com/a033e5b3-0...
# 7   https://media-cdn.cortextech.io/cbc49cb0-99ce-...
# 8   https://media-cdn.incrowdsports.com/35dfa503-e...
# 9   https://media-cdn.incrowdsports.com/e3dff28a-9...
# 10  https://media-cdn.incrowdsports.com/cbb1c3ad-0...
# 11  https://media-cdn.cortextech.io/9512ee73-a0f1-...
# 12  https://media-cdn.incrowdsports.com/d2eef4a8-6...
# 13  https://media-cdn.incrowdsports.com/1efae090-1...
# 14  https://media-cdn.cortextech.io/1b533342-78f5-...
# 15  https://media-cdn.incrowdsports.com/0aa09358-3...
# 16  https://media-cdn.cortextech.io/d88f3c71-1519-...
# 17  https://media-cdn.incrowdsports.com/371b0d9b-9...
# 18  https://media-cdn.incrowdsports.com/89ed276a-2...
# 19  https://media-cdn.incrowdsports.com/789423ac-3...

# %%
team_stats_2024_df["offensiveReboundsPercentage"] = team_stats_2024_df["offensiveReboundsPercentage"].str.strip("%").astype(float)
team_stats_2024_df["defensiveReboundsPercentage"] = team_stats_2024_df["defensiveReboundsPercentage"].str.strip("%").astype(float)

# %%
team_stats_2024_df.sort_values("offensiveReboundsPercentage").plot.bar(x="team.name", y="offensiveReboundsPercentage")

# %%
fig=team_stats_2024_df.plot.scatter(x="offensiveReboundsPercentage",y="defensiveReboundsPercentage",hover_data=["team.name"])
fig.update_traces(mode="markers+text",text=team_stats_2024_df["team.name"],
                  textposition="top center",
                  )
fig.show()

# %%
team_stats_2024_dffortheteam = teamstats.get_team_stats(
    endpoint="traditional",
    params={"SeasonMode": "Single", "SeasonCode": "E2024"},
    statistic_mode="Accumulated"
)

team_stats_opps_2024_df = teamstats.get_team_stats(
    endpoint="opponentsTraditional",
    params={"SeasonMode": "Single", "SeasonCode": "E2024"},
    statistic_mode="Accumulated"
)

# %%
team_stats_2024_dffortheteam
team_stats_2024_dffortheteam["possessions"] = get_team_possessions(team_stats_2024_dffortheteam)

# %%
team_stats_2024_dffortheteam
# Out:
#     teamRanking  gamesPlayed  minutesPlayed  pointsScored  twoPointersMade  \
# 0             1         34.0         1375.0        2675.0            769.0
# 1             2         34.0         1365.0        2632.0            577.0
# 2             3         34.0         1365.0        2751.0            640.0
# 3             4         34.0         1365.0        2693.0            688.0
# 4             5         34.0         1360.0        2780.0            703.0
# 5             6         34.0         1365.0        2807.0            713.0
# 6             7         35.0         1425.0        2907.0            708.0
# 7             8         34.0         1360.0        2921.0            782.0
# 8             9         34.0         1365.0        2905.0            647.0
# 9            10         36.0         1445.0        3133.0            647.0
# 10           11         38.0         1525.0        3259.0            775.0
# 11           12         39.0         1565.0        3262.0            695.0
# 12           13         40.0         1610.0        3366.0            838.0
# 13           14         39.0         1575.0        3418.0            902.0
# 14           15         39.0         1565.0        3341.0            857.0
# 15           16         41.0         1650.0        3518.0            927.0
# 16           17         40.0         1605.0        3438.0            809.0
# 17           18         41.0         1645.0        3575.0            879.0
#
#     twoPointersAttempted twoPointersPercentage  threePointersMade  \
# 0                 1406.0                 54.7%              246.0
# 1                 1106.0                 52.2%              325.0
# 2                 1186.0                   54%              309.0
# 3                 1252.0                   55%              258.0
# 4                 1297.0                 54.2%              305.0
# 5                 1305.0                 54.6%              306.0
# 6                 1285.0                 55.1%              328.0
# 7                 1432.0                 54.6%              274.0
# 8                 1198.0                   54%              339.0
# 9                 1124.0                 57.6%              452.0
# 10                1414.0                 54.8%              398.0
# 11                1321.0                 52.6%              438.0
# 12                1413.0                 59.3%              369.0
# 13                1567.0                 57.6%              373.0
# 14                1482.0                 57.8%              371.0
# 15                1669.0                 55.5%              336.0
# 16                1408.0                 57.5%              380.0
# 17                1523.0                 57.7%              396.0
#
#     threePointersAttempted threePointersPercentage  ...  blocks  \
# 0                    818.0                   30.1%  ...    70.0
# 1                    948.0                   34.3%  ...    92.0
# 2                    848.0                   36.4%  ...    81.0
# 3                    827.0                   31.2%  ...    79.0
# 4                    817.0                   37.3%  ...   101.0
# 5                    888.0                   34.5%  ...   100.0
# 6                    904.0                   36.3%  ...    63.0
# 7                    765.0                   35.8%  ...    53.0
# 8                    858.0                   39.5%  ...    68.0
# 9                   1152.0                   39.2%  ...    45.0
# 10                  1145.0                   34.8%  ...    78.0
# 11                  1145.0                   38.3%  ...    97.0
# 12                  1099.0                   33.6%  ...   110.0
# 13                   967.0                   38.6%  ...    71.0
# 14                   954.0                   38.9%  ...   156.0
# 15                   932.0                   36.1%  ...   111.0
# 16                  1040.0                   36.5%  ...    94.0
# 17                  1038.0                   38.2%  ...   105.0
#
#     blocksAgainst foulsCommited  foulsDrawn     pir  team.code  team.tvCodes  \
# 0           121.0         742.0       645.0  2700.0        BER           BER
# 1            81.0         775.0       708.0  2703.0        ZAL           ZAL
# 2           100.0         734.0       698.0  2931.0        ASV           ASV
# 3            79.0         709.0       714.0  2956.0        VIR           VIR
# 4            87.0         696.0       657.0  3093.0        PAR           PAR
# 5           109.0         600.0       644.0  3149.0        BAS           BKN
# 6            83.0         734.0       713.0  3201.0        RED           CZV
# 7            88.0         683.0       701.0  3245.0        TEL           MTA
# 8            63.0         667.0       737.0  3268.0        MIL           EA7
# 9            91.0         733.0       685.0  3350.0        MUN           BAY
# 10          101.0         823.0       742.0  3382.0        PRS           PBB
# 11           65.0         827.0       784.0  3611.0        ULK           FBB
# 12           83.0         822.0       821.0  3844.0        MAD           RMB
# 13           72.0         817.0       768.0  3867.0        BAR           BAR
# 14           82.0         763.0       744.0  3883.0        IST           EFS
# 15           86.0         891.0       895.0  3983.0        MCO           ASM
# 16           76.0         748.0       836.0  4031.0        OLY           OLY
# 17          107.0         739.0       850.0  4215.0        PAN           PAO
#
#                              team.name  \
# 0                          ALBA Berlin
# 1                      Zalgiris Kaunas
# 2              LDLC ASVEL Villeurbanne
# 3                       Virtus Bologna
# 4        Partizan Mozzart Bet Belgrade
# 5             Baskonia Vitoria-Gasteiz
# 6   Crvena Zvezda Meridianbet Belgrade
# 7               Maccabi Rapyd Tel Aviv
# 8             EA7 Emporio Armani Milan
# 9                     FC Bayern Munich
# 10                    Paris Basketball
# 11            Fenerbahce Beko Istanbul
# 12                         Real Madrid
# 13                        FC Barcelona
# 14               Anadolu Efes Istanbul
# 15                           AS Monaco
# 16                  Olympiacos Piraeus
# 17          Panathinaikos AKTOR Athens
#
#                                         team.imageUrl  possessions
# 0   https://media-cdn.incrowdsports.com/ccc34858-2...      2593.56
# 1   https://media-cdn.incrowdsports.com/0aa09358-3...      2403.04
# 2   https://media-cdn.incrowdsports.com/e33c6d1a-9...      2463.36
# 3   https://media-cdn.cortextech.io/1362801d-dd09-...      2445.76
# 4   https://media-cdn.incrowdsports.com/2681304e-7...      2379.20
# 5   https://media-cdn.cortextech.io/cbc49cb0-99ce-...      2452.32
# 6   https://media-cdn.incrowdsports.com/d2eef4a8-6...      2534.72
# 7   https://media-cdn.cortextech.io/1b533342-78f5-...      2520.16
# 8   https://media-cdn.cortextech.io/9512ee73-a0f1-...      2481.04
# 9   https://media-cdn.incrowdsports.com/817b0e58-d...      2645.88
# 10  https://media-cdn.incrowdsports.com/a033e5b3-0...      2802.92
# 11  https://media-cdn.cortextech.io/3b7f020e-5b39-...      2783.64
# 12  https://media-cdn.incrowdsports.com/371b0d9b-9...      2956.88
# 13  https://media-cdn.incrowdsports.com/35dfa503-e...      2883.08
# 14  https://media-cdn.cortextech.io/9a463aa2-ceb2-...      2794.68
# 15  https://media-cdn.incrowdsports.com/89ed276a-2...      2990.88
# 16  https://media-cdn.incrowdsports.com/789423ac-3...      2884.24
# 17  https://media-cdn.incrowdsports.com/e3dff28a-9...      2973.12
#
# [18 rows x 29 columns]
